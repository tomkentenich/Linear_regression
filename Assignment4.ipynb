# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df1=pd.read_csv('data/train.csv')
df2=pd.read_csv('data/test.csv')

# %%
df1.isnull().sum()
# Out:
# ID         0
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df1.plot(x='CRIM',y='MEDV',style='o')
# Out:
# <AxesSubplot:xlabel='CRIM'>

# %%
df1[['CRIM','MEDV']].corr()
# Out:
#           CRIM      MEDV
# CRIM  1.000000 -0.393693
# MEDV -0.393693  1.000000

# %%
from matplotlib import pyplot as plt
corr=df1.corr()
plt.figure(figsize=(11,8))
sns.heatmap(corr, cmap="Oranges",annot=True)
plt.show()

# %%
X_train=df1.iloc[:,:-1].values
y_train=df1.iloc[:,-1].values
X_test=df2.iloc[:,:]

# %%
from sklearn.linear_model import Lasso
regressor=Lasso()
regressor.fit(X_train,y_train)
# Out:
# Lasso()

# %%
l1y_pred=regressor.predict(X_test)
pd.DataFrame({'predicted Salary':y_pred})
# Out:
#      predicted Salary
# 0           23.212092
# 1           25.244005
# 2           15.241276
# 3           19.537353
# 4           21.828720
# ..                ...
# 100         24.630242
# 101         16.759386
# 102         27.693429
# 103         35.493163
# 104         11.710574
#
# [105 rows x 1 columns]

# %%
from sklearn.linear_model import Ridge
regressor=Ridge()
regressor.fit(X_train,y_train)
# Out:
# Ridge()

# %%
l2y_pred=regressor.predict(X_test)
pd.DataFrame({'predicted Salary':y_pred})
# Out:
#      predicted Salary
# 0           23.212092
# 1           25.244005
# 2           15.241276
# 3           19.537353
# 4           21.828720
# ..                ...
# 100         24.630242
# 101         16.759386
# 102         27.693429
# 103         35.493163
# 104         11.710574
#
# [105 rows x 1 columns]
